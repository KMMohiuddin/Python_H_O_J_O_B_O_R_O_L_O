# %%
from bs4 import BeautifulSoup
import requests

# %%
import time
import datetime
import smtplib

# %%
try:
    src = requests.get("https://www.bb.org.bd/en/index.php/financialactivity/mfsdata")
    src.raise_for_status()  #it will through an error if website not found

    soup = BeautifulSoup(src.text,'html.parser')
    print(soup.prettify())

except Exception as e:
    print(e)
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Tell the browser to be responsive to screen width -->
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Bangladesh Bank
#   </title>
#   <link href="/en/assets/img/website/favicon.png" rel="icon" type="image/png"/>
#   <!-- Font Awesome -->
#   <!--<link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700,900">-->
#   <script src="/en/assets/js/jquery.min.js">
#   </script>
#   <link href="/en/assets/fonts/fonts.css" rel="stylesheet"/>
#   <link href="/en/assets/plugins/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/en/assets/css/bbicons.css" rel="stylesheet" type="text/css"/>
#   <link href="/en/assets/plugins/swiper/swiper.css" rel="stylesheet" type="text/css"/>
#   <link href="/en/assets/css/datatables.min.css" rel="stylesheet"/>
# ...

# %%
src = requests.get("https://www.bb.org.bd/en/index.php/financialactivity/mfsdata")
src.raise_for_status()  #it will through an error if website not found

soup = BeautifulSoup(src.text,'html.parser')

res = soup.table
#print(res.prettify())
#print(res.get_text())


#print(soup.prettify())
# Out:
# Serial no.
# Description
# Amount in February, 2023
# Amount in March, 2023
# % Change (February, 2023 to March, 2023)
#
#
# A.
# Industry Wise Information
#
# ...

# %%
import csv
# Send a GET request to the website
url = 'https://www.bb.org.bd/en/index.php/financialactivity/mfsdata'
response = requests.get(url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Access the HTML content of the webpage
    html_content = response.text

    # Parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')

    # Find the table and its rows
    table = soup.find('table')
    rows = table.find_all('tr')

    # Specify the range of rows to scrape (1-3 in this example)
    start_row = 1
    end_row = 20

    # Open a CSV file for writing
    with open('BB_table_data.csv', 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)

        # Iterate over the specified range of rows
        for row in rows[start_row:end_row+1]:
            # Find all the cells in the current row
            cells = row.find_all('td')

            # Extract the text from each cell and write it to the CSV file
            csvwriter.writerow([cell.get_text() for cell in cells])

    print("Scraping and CSV conversion complete.")
else:
    # Handle the case when the request was not successful
    print(f"Request failed with status code {response.status_code}")
# Out:
# Scraping and CSV conversion complete.
